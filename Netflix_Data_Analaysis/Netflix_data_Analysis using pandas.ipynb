# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
netflix=pd.read_csv('netflix.csv')

# %%
netflix
# Out:
#      show_id     type                  title         director        country  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson  United States
# 1         s2  TV Show          Blood & Water              NaN   South Africa
# 2         s3  TV Show              Ganglands  Julien Leclercq            NaN
# 3         s4  TV Show  Jailbirds New Orleans              NaN            NaN
# 4         s5  TV Show           Kota Factory              NaN          India
# ...      ...      ...                    ...              ...            ...
# 8802   s8803    Movie                 Zodiac    David Fincher  United States
# 8803   s8804  TV Show            Zombie Dumb              NaN            NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer  United States
# 8805   s8806    Movie                   Zoom     Peter Hewitt  United States
# 8806   s8807    Movie                 Zubaan      Mozez Singh          India
#
# ...

# %%
netflix.shape
# Out:
# (8807, 10)

# %%
movies=netflix[netflix['type']=='Movie']

# %%
movies
# Out:
#      show_id   type                             title  \
# 0         s1  Movie              Dick Johnson Is Dead
# 6         s7  Movie  My Little Pony: A New Generation
# 7         s8  Movie                           Sankofa
# 9        s10  Movie                      The Starling
# 12       s13  Movie                      Je Suis Karl
# ...      ...    ...                               ...
# 8801   s8802  Movie                           Zinzana
# 8802   s8803  Movie                            Zodiac
# 8804   s8805  Movie                        Zombieland
# 8805   s8806  Movie                              Zoom
# 8806   s8807  Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# 9                    Theodore Melfi
# 12              Christian Schwochow
# ...                             ...
# 8801                Majid Al Ansari
# ...

# %%
netflix[netflix['type']=='Movie'].shape
# Out:
# (6131, 10)

# %%
movies.shape
# Out:
# (6131, 10)

# %%
Tvshows=netflix[netflix['type']=='TV Show']

# %%
Tvshows
# Out:
#      show_id     type                  title         director  \
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# 5         s6  TV Show          Midnight Mass    Mike Flanagan
# ...      ...      ...                    ...              ...
# 8795   s8796  TV Show        Yu-Gi-Oh! Arc-V              NaN
# 8796   s8797  TV Show             Yunus Emre              NaN
# 8797   s8798  TV Show              Zak Storm              NaN
# 8800   s8801  TV Show     Zindagi Gulzar Hai              NaN
# 8803   s8804  TV Show            Zombie Dumb              NaN
#
#                                             country          date_added  \
# 1                                      South Africa  September 24, 2021
# 2                                               NaN  September 24, 2021
# ...

# %%
Tvshows.shape
# Out:
# (2676, 10)

# %%
netflix.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# dtype: int64

# %%
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   country       7976 non-null   object
#  5   date_added    8797 non-null   object
#  6   release_year  8807 non-null   int64
#  7   rating        8803 non-null   object
#  8   duration      8804 non-null   object
#  9   listed_in     8807 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 688.2+ KB

# %%
netflix.dropna(inplace=True)

# %%
netflix
# Out:
#      show_id     type                          title             director  \
# 0         s1    Movie           Dick Johnson Is Dead      Kirsten Johnson
# 7         s8    Movie                        Sankofa         Haile Gerima
# 8         s9  TV Show  The Great British Baking Show      Andy Devonshire
# 9        s10    Movie                   The Starling       Theodore Melfi
# 12       s13    Movie                   Je Suis Karl  Christian Schwochow
# ...      ...      ...                            ...                  ...
# 8801   s8802    Movie                        Zinzana      Majid Al Ansari
# 8802   s8803    Movie                         Zodiac        David Fincher
# 8804   s8805    Movie                     Zombieland      Ruben Fleischer
# 8805   s8806    Movie                           Zoom         Peter Hewitt
# 8806   s8807    Movie                         Zubaan          Mozez Singh
#
#                                                 country          date_added  \
# ...

# %%
in2021=netflix[netflix['release_year']>2020]

# %%
in2021
# Out:
#      show_id     type                                        title  \
# 8         s9  TV Show                The Great British Baking Show
# 9        s10    Movie                                 The Starling
# 12       s13    Movie                                 Je Suis Karl
# 81       s82    Movie                                         Kate
# 91       s92    Movie                   The Women and the Murderer
# ...      ...      ...                                          ...
# 1416   s1417  TV Show  Night Stalker: The Hunt for a Serial Killer
# 1420   s1421    Movie      Crack: Cocaine, Corruption & Conspiracy
# 1424   s1425    Movie                                     Charming
# 1432   s1433  TV Show                         The Idhun Chronicles
# 1468   s1469    Movie                    What Happened to Mr. Cha?
#
#                                 director  \
# 8                        Andy Devonshire
# 9                         Theodore Melfi
# ...

# %%
in2021[in2021['type']=='Movie']
# Out:
#      show_id   type                                    title  \
# 9        s10  Movie                             The Starling
# 12       s13  Movie                             Je Suis Karl
# 81       s82  Movie                                     Kate
# 91       s92  Movie               The Women and the Murderer
# 101     s102  Movie                   Untold: Breaking Point
# ...      ...    ...                                      ...
# 1411   s1412  Movie              What Would Sophia Loren Do?
# 1412   s1413  Movie                                 Wish You
# 1420   s1421  Movie  Crack: Cocaine, Corruption & Conspiracy
# 1424   s1425  Movie                                 Charming
# 1468   s1469  Movie                What Happened to Mr. Cha?
#
#                                 director  \
# 9                         Theodore Melfi
# 12                   Christian Schwochow
# 81                 Cedric Nicolas-Troyan
# 91    Mona Achache, Patricia Tourancheau
# ...

# %%
in2021['type']=='TV Show'
# Out:
# 8        True
# 9       False
# 12      False
# 81      False
# 91      False
#         ...
# 1416     True
# 1420    False
# 1424    False
# 1432     True
# 1468    False
# Name: type, Length: 185, dtype: bool

# %%
in2021[in2021['type']=='TV Show']
# Out:
#      show_id     type                                          title  \
# 8         s9  TV Show                  The Great British Baking Show
# 198     s199  TV Show           King of Boys: The Return of the King
# 273     s274  TV Show                                  Gone for Good
# 276     s277  TV Show                                        Valeria
# 297     s298  TV Show                                       Navarasa
# 310     s311  TV Show            Cocaine Cowboys: The Kings of Miami
# 380     s381  TV Show                                      The Flash
# 503     s504  TV Show                                       The Mire
# 737     s738  TV Show                                          Trese
# 758     s759  TV Show                                      Feel Good
# 879     s880  TV Show                                        Halston
# 919     s920  TV Show       The Sons of Sam: A Descent into Darkness
# 988     s989  TV Show                              Let's Fight Ghost
# ...

# %%
in2021[in2021['type']=='TV Show'].shape
# Out:
# (24, 10)

# %%
in2021[in2021['type']=='Movie'].shape
# Out:
# (161, 10)

# %%
m21=in2021[in2021['type']=='Movie']

# %%
m21[m21['country']=='India'].shape
# Out:
# (21, 10)

# %%
ind=netflix[netflix['country']=='India']

# %%
ind
# Out:
#      show_id   type                  title                 director country  \
# 24       s25  Movie                  Jeans               S. Shankar   India
# 105     s106  Movie       Angamaly Diaries     Lijo Jose Pellissery   India
# 114     s115  Movie                 Anjaam             Rahul Rawail   India
# 116     s117  Movie                 Dhanak          Nagesh Kukunoor   India
# 118     s119  Movie                Gurgaon            Shanker Raman   India
# ...      ...    ...                    ...                      ...     ...
# 8772   s8773  Movie  Yamla Pagla Deewana 2           Sangeeth Sivan   India
# 8773   s8774  Movie    Yanda Kartavya Aahe             Kedar Shinde   India
# 8798   s8799  Movie               Zed Plus  Chandra Prakash Dwivedi   India
# 8799   s8800  Movie                  Zenda           Avadhoot Gupte   India
# 8806   s8807  Movie                 Zubaan              Mozez Singh   India
#
# ...

# %%
ind.shape
# Out:
# (890, 10)

# %%
ind[ind['type']=='Movie']
# Out:
#      show_id   type                  title                 director country  \
# 24       s25  Movie                  Jeans               S. Shankar   India
# 105     s106  Movie       Angamaly Diaries     Lijo Jose Pellissery   India
# 114     s115  Movie                 Anjaam             Rahul Rawail   India
# 116     s117  Movie                 Dhanak          Nagesh Kukunoor   India
# 118     s119  Movie                Gurgaon            Shanker Raman   India
# ...      ...    ...                    ...                      ...     ...
# 8772   s8773  Movie  Yamla Pagla Deewana 2           Sangeeth Sivan   India
# 8773   s8774  Movie    Yanda Kartavya Aahe             Kedar Shinde   India
# 8798   s8799  Movie               Zed Plus  Chandra Prakash Dwivedi   India
# 8799   s8800  Movie                  Zenda           Avadhoot Gupte   India
# 8806   s8807  Movie                 Zubaan              Mozez Singh   India
#
# ...

# %%
ind[ind['type']=='TV Show']
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, country, date_added, release_year, rating, duration, listed_in]
# Index: []

# %%
ind[ind[ind['type']=='Movie']['listed_in']=='Comedies, International Movies, Romantic Movies']
# Out:
#      show_id   type                         title                director  \
# 24       s25  Movie                         Jeans              S. Shankar
# 1423   s1424  Movie                  BluffMaster!             Rohan Sippy
# 1863   s1864  Movie                      Hunterrr  Harshavardhan Kulkarni
# 1869   s1870  Movie              Ginny Weds Sunny           Puneet Khanna
# 1942   s1943  Movie                       Ishqiya        Abhishek Chaubey
# 2082   s2083  Movie          Maniyarayile Ashokan            Shamzu Zayba
# 2280   s2281  Movie           Mumbai Delhi Mumbai          Satish Rajwade
# 2728   s2729  Movie     Humpty Sharma Ki Dulhania        Shashank Khaitan
# 2735   s2736  Movie                   Magnificent              Vikas Bahl
# 2815   s2816  Movie                  Jai Mummy Di           Navjot Gulati
# 2985   s2986  Movie                 Shimla Mirchi            Ramesh Sippy
# 3189   s3190  Movie                    Baby Dolls       Vijay Kumar Arora
# ...

# %%
netflix.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in'],
#       dtype='object')

# %%
ind[ind[ind['type']=='Movie']['listed_in']=='Comedies, International Movies, Romantic Movies'].shape
# Out:
# (41, 10)

# %%
ind[ind[ind['type']=='Movie']['listed_in']=='Dramas, International Movies, Thrillers'].shape
# Out:
# (43, 10)

# %%
ind[ind[ind['type']=='Movie']['listed_in']=='Action & Adventure, Comedies, Dramas'].shape
# Out:
# (17, 10)

# %%
ind[ind[ind['type']=='Movie']['listed_in']=='Comedies, Dramas, Independent Movies'].shape
# Out:
# (25, 10)

# %%
netflix
# Out:
#      show_id     type                          title             director  \
# 0         s1    Movie           Dick Johnson Is Dead      Kirsten Johnson
# 7         s8    Movie                        Sankofa         Haile Gerima
# 8         s9  TV Show  The Great British Baking Show      Andy Devonshire
# 9        s10    Movie                   The Starling       Theodore Melfi
# 12       s13    Movie                   Je Suis Karl  Christian Schwochow
# ...      ...      ...                            ...                  ...
# 8801   s8802    Movie                        Zinzana      Majid Al Ansari
# 8802   s8803    Movie                         Zodiac        David Fincher
# 8804   s8805    Movie                     Zombieland      Ruben Fleischer
# 8805   s8806    Movie                           Zoom         Peter Hewitt
# 8806   s8807    Movie                         Zubaan          Mozez Singh
#
#                                                 country          date_added  \
# ...
