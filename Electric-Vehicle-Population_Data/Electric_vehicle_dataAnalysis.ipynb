# %% [markdown]
# Install the libraries before importing the libraries since pandas and numpy are libraries of python those are already installed.
# so i started with importing the pandas and numpy library to analyze the data using data frames.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Consider the data from one of official data open source  website to analyse the various things. Then i downloded and placed in the location of my jupyter notebook.

# %% [markdown]
# then start read the data set using the pandas library and here i used csv file so we can read the file using below command.

# %%
electric_vehicle_data=pd.read_csv('Electric_Vehicle_Population_Data (1).csv')

# %%
electric_vehicle_data
# Out:
#         VIN (1-10)    County           City State  Postal Code  Model Year  \
# 0       5YJXCAE26J    Yakima         Yakima    WA      98908.0        2018
# 1       JHMZC5F37M    Kitsap        Poulsbo    WA      98370.0        2021
# 2       5YJ3E1EB0K      King        Seattle    WA      98199.0        2019
# 3       1N4AZ0CP5D      King        Seattle    WA      98119.0        2013
# 4       5YJSA1E21H  Thurston          Lacey    WA      98516.0        2017
# ...            ...       ...            ...   ...          ...         ...
# 130438  7SAYGDEE6P    Pierce     Gig Harbor    WA      98335.0        2023
# 130439  1N4BZ1CV7N    Pierce         Tacoma    WA      98408.0        2022
# 130440  5YJYGDEE8M      King        Seattle    WA      98109.0        2021
# 130441  5YJXCBE22L    Island  Camano Island    WA      98282.0        2020
# 130442  5YJ3E1EA5M    Pierce       Puyallup    WA      98375.0        2021
#
#           Make    Model                   Electric Vehicle Type  \
# ...

# %% [markdown]
# As we can see the data we have read i.e electric vehicle data and also we absorb many field regarding different things.

# %% [markdown]
# # Since there are some fields which we are not going to use to analysis the different things related to electric vehicles so i drop them from the data sets

# %%
electric_vehicle_data.drop(['Base MSRP'],axis=1,inplace=True)

# %%
electric_vehicle_data.drop(['DOL Vehicle ID'],axis=1,inplace=True)

# %% [markdown]
# Lets findout the each field data types and which constraint does it has with help of info command as you can see here.
# different fields having int data type, some are of object data type and few more float data of 64 bit

# %%
electric_vehicle_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130443 entries, 0 to 130442
# Data columns (total 14 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   VIN (1-10)                                         130443 non-null  object
#  1   County                                             130440 non-null  object
#  2   City                                               130440 non-null  object
#  3   State                                              130443 non-null  object
#  4   Postal Code                                        130440 non-null  float64
#  5   Model Year                                         130443 non-null  int64
#  6   Make                                               130443 non-null  object
#  7   Model                                              130221 non-null  object
# ...

# %% [markdown]
# We can findout the no.of rows does every field having that we can find using count that we can abosrt as below.

# %%
electric_vehicle_data['City'].count()
# Out:
# 130440

# %% [markdown]
# Lets findout the dimensions of the data set of their rows and columns by using the formula like shape command.

# %%
electric_vehicle_data.shape
# Out:
# (130443, 14)

# %% [markdown]
# Lets view the full data frame after removing the columns which are unnecessary

# %%
electric_vehicle_data
# Out:
#         VIN (1-10)    County           City State  Postal Code  Model Year  \
# 0       5YJXCAE26J    Yakima         Yakima    WA      98908.0        2018
# 1       JHMZC5F37M    Kitsap        Poulsbo    WA      98370.0        2021
# 2       5YJ3E1EB0K      King        Seattle    WA      98199.0        2019
# 3       1N4AZ0CP5D      King        Seattle    WA      98119.0        2013
# 4       5YJSA1E21H  Thurston          Lacey    WA      98516.0        2017
# ...            ...       ...            ...   ...          ...         ...
# 130438  7SAYGDEE6P    Pierce     Gig Harbor    WA      98335.0        2023
# 130439  1N4BZ1CV7N    Pierce         Tacoma    WA      98408.0        2022
# 130440  5YJYGDEE8M      King        Seattle    WA      98109.0        2021
# 130441  5YJXCBE22L    Island  Camano Island    WA      98282.0        2020
# 130442  5YJ3E1EA5M    Pierce       Puyallup    WA      98375.0        2021
#
#           Make    Model                   Electric Vehicle Type  \
# ...

# %% [markdown]
# To findout each column names present in a data set we use the command of columns with reference to the variable which we have
# assigned before to the data frame.

# %%
electric_vehicle_data.columns
# Out:
# Index(['VIN (1-10)', 'County', 'City', 'State', 'Postal Code', 'Model Year',
#        'Make', 'Model', 'Electric Vehicle Type',
#        'Clean Alternative Fuel Vehicle (CAFV) Eligibility', 'Electric Range',
#        'Legislative District', 'Electric Utility', '2020 Census Tract'],
#       dtype='object')

# %% [markdown]
# Just to analyse the basic things and what are the records with respect to their columns for their initial we can use the command of head or to find the last few records we can use tail commands.

# %%
electric_vehicle_data.head()
# Out:
#    VIN (1-10)    County     City State  Postal Code  Model Year    Make  \
# 0  5YJXCAE26J    Yakima   Yakima    WA      98908.0        2018   TESLA
# 1  JHMZC5F37M    Kitsap  Poulsbo    WA      98370.0        2021   HONDA
# 2  5YJ3E1EB0K      King  Seattle    WA      98199.0        2019   TESLA
# 3  1N4AZ0CP5D      King  Seattle    WA      98119.0        2013  NISSAN
# 4  5YJSA1E21H  Thurston    Lacey    WA      98516.0        2017   TESLA
#
#      Model                   Electric Vehicle Type  \
# 0  MODEL X          Battery Electric Vehicle (BEV)
# 1  CLARITY  Plug-in Hybrid Electric Vehicle (PHEV)
# 2  MODEL 3          Battery Electric Vehicle (BEV)
# 3     LEAF          Battery Electric Vehicle (BEV)
# 4  MODEL S          Battery Electric Vehicle (BEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible             238
# 1           Clean Alternative Fuel Vehicle Eligible              47
# ...

# %%
electric_vehicle_data.tail()
# Out:
#         VIN (1-10)  County           City State  Postal Code  Model Year  \
# 130438  7SAYGDEE6P  Pierce     Gig Harbor    WA      98335.0        2023
# 130439  1N4BZ1CV7N  Pierce         Tacoma    WA      98408.0        2022
# 130440  5YJYGDEE8M    King        Seattle    WA      98109.0        2021
# 130441  5YJXCBE22L  Island  Camano Island    WA      98282.0        2020
# 130442  5YJ3E1EA5M  Pierce       Puyallup    WA      98375.0        2021
#
#           Make    Model           Electric Vehicle Type  \
# 130438   TESLA  MODEL Y  Battery Electric Vehicle (BEV)
# 130439  NISSAN     LEAF  Battery Electric Vehicle (BEV)
# 130440   TESLA  MODEL Y  Battery Electric Vehicle (BEV)
# 130441   TESLA  MODEL X  Battery Electric Vehicle (BEV)
# 130442   TESLA  MODEL 3  Battery Electric Vehicle (BEV)
#
#         Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 130438  Eligibility unknown as battery range has not b...               0
# ...

# %% [markdown]
# To find out the data set records size i.e how many records present in the data frame can be find by using the command of len(reference variable which we have assigned to the data frame)

# %%
len(electric_vehicle_data)
# Out:
# 130443

# %% [markdown]
# To findout how may records are null with respect to their columns can be find by using isnull.sum() with respect to it's reference variable. that you can see here.

# %%
electric_vehicle_data.isnull().sum()
# Out:
# VIN (1-10)                                             0
# County                                                 3
# City                                                   3
# State                                                  0
# Postal Code                                            3
# Model Year                                             0
# Make                                                   0
# Model                                                222
# Electric Vehicle Type                                  0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# Electric Range                                         0
# Legislative District                                 305
# Electric Utility                                       3
# 2020 Census Tract                                      3
# dtype: int64

# %% [markdown]
# After we have removed the columns which are not useful the data frame looks like as below. and the len(columns) will be reduced to 14.

# %%
electric_vehicle_data
# Out:
#         VIN (1-10)    County           City State  Postal Code  Model Year  \
# 0       5YJXCAE26J    Yakima         Yakima    WA      98908.0        2018
# 1       JHMZC5F37M    Kitsap        Poulsbo    WA      98370.0        2021
# 2       5YJ3E1EB0K      King        Seattle    WA      98199.0        2019
# 3       1N4AZ0CP5D      King        Seattle    WA      98119.0        2013
# 4       5YJSA1E21H  Thurston          Lacey    WA      98516.0        2017
# ...            ...       ...            ...   ...          ...         ...
# 130438  7SAYGDEE6P    Pierce     Gig Harbor    WA      98335.0        2023
# 130439  1N4BZ1CV7N    Pierce         Tacoma    WA      98408.0        2022
# 130440  5YJYGDEE8M      King        Seattle    WA      98109.0        2021
# 130441  5YJXCBE22L    Island  Camano Island    WA      98282.0        2020
# 130442  5YJ3E1EA5M    Pierce       Puyallup    WA      98375.0        2021
#
#           Make    Model                   Electric Vehicle Type  \
# ...

# %% [markdown]
# After removal of unnecessary columns the dimensions of data set.

# %%
electric_vehicle_data.shape
# Out:
# (130443, 14)

# %% [markdown]
# Listing out the no.of models made by each maker.

# %%
electric_vehicle_data.groupby(['Make'])['Model'].count().reset_index(name='total_no.of_models')
# Out:
#                     Make  total_no.of_models
# 0                   AUDI                2622
# 1         AZURE DYNAMICS                   7
# 2                BENTLEY                   3
# 3                    BMW                5696
# 4               CADILLAC                 103
# 5              CHEVROLET               11251
# 6               CHRYSLER                2139
# 7                   FIAT                 803
# 8                 FISKER                  14
# 9                   FORD                6743
# 10               GENESIS                  54
# 11                 HONDA                 791
# 12               HYUNDAI                2144
# 13                JAGUAR                 222
# 14                  JEEP                2328
# 15                   KIA                5252
# 16            LAND ROVER                  41
# 17                 LEXUS                  64
# 18               LINCOLN                 208
# 19                 LUCID                 133
# ...

# %% [markdown]
# No.of models made by different makers in descending order.

# %%
list_by_make_model=electric_vehicle_data.groupby(['Make'])['Model'].count().reset_index(name='total_no.of_models')

# %%
list_by_make_model.sort_values(by='total_no.of_models',ascending=False)
# Out:
#                     Make  total_no.of_models
# 29                 TESLA               59629
# 23                NISSAN               13023
# 5              CHEVROLET               11251
# 9                   FORD                6743
# 3                    BMW                5696
# 15                   KIA                5252
# 31                TOYOTA                4770
# 32            VOLKSWAGEN                3432
# 33                 VOLVO                2891
# 0                   AUDI                2622
# 14                  JEEP                2328
# 12               HYUNDAI                2144
# 6               CHRYSLER                2139
# 26                RIVIAN                1612
# 25               PORSCHE                 936
# 7                   FIAT                 803
# 11                 HONDA                 791
# 21                  MINI                 728
# 20         MERCEDES-BENZ                 711
# 22            MITSUBISHI                 710
# ...

# %% [markdown]
# list_by_make_model.shape

# %% [markdown]
# list_by_make_model[list_by_make_model['Make']=='AUDI']

# %%
top_15=list_by_make_model.sort_values(by='total_no.of_models',ascending=False).head(15)

# %%
top_15
# Out:
#           Make  total_no.of_models
# 29       TESLA               59629
# 23      NISSAN               13023
# 5    CHEVROLET               11251
# 9         FORD                6743
# 3          BMW                5696
# 15         KIA                5252
# 31      TOYOTA                4770
# 32  VOLKSWAGEN                3432
# 33       VOLVO                2891
# 0         AUDI                2622
# 14        JEEP                2328
# 12     HYUNDAI                2144
# 6     CHRYSLER                2139
# 26      RIVIAN                1612
# 25     PORSCHE                 936

# %% [markdown]
# Total No.of models made by the maker of Audi is

# %%
list_by_make_model[list_by_make_model['Make']=='AUDI']
# Out:
#    Make  total_no.of_models
# 0  AUDI                2622

# %% [markdown]
# Sorting the entire data set on the basis of year of model

# %%
modelyear=electric_vehicle_data.sort_values(by='Model Year', ascending=False)

# %%
modelyear
# Out:
#         VIN (1-10)     County          City State  Postal Code  Model Year  \
# 91343   KMUKEDTB4P     Chelan      Cashmere    WA      98815.0        2023
# 113473  7SAYGDEF8P  Snohomish      Lynnwood    WA      98036.0        2023
# 85193   YV4ED3UM3P  Snohomish      Lynnwood    WA      98037.0        2023
# 25368   7SAYGDEE5P       King     Sammamish    WA      98075.0        2023
# 25369   1G1FY6S05P     Kitsap       Poulsbo    WA      98370.0        2023
# ...            ...        ...           ...   ...          ...         ...
# 78048   1FTZR0813X     Pierce        Graham    WA      98338.0        1999
# 83309   1FTZR0812X     Skagit  Mount Vernon    WA      98274.0        1999
# 91445   1FTZR0812X     Pierce        Graham    WA      98338.0        1999
# 28188   1FTZR1078W    Clallam        Sequim    WA      98382.0        1998
# 121626  1GCDE14HXV  Snohomish    Marysville    WA      98270.0        1997
#
#              Make        Model           Electric Vehicle Type  \
# ...

# %% [markdown]
# sorting the no.of models with year of model made by each maker in ascending order

# %%
modelyear.groupby(['Model Year','Make'])['Model'].count().reset_index(name='no.of_models')
# Out:
#      Model Year        Make  no.of_models
# 0          1997   CHEVROLET             1
# 1          1998        FORD             1
# 2          1999        FORD             4
# 3          2000        FORD             9
# 4          2002      TOYOTA             2
# ..          ...         ...           ...
# 217        2023      SUBARU           167
# 218        2023       TESLA          8472
# 219        2023      TOYOTA           183
# 220        2023  VOLKSWAGEN           699
# 221        2023       VOLVO           461
#
# [222 rows x 3 columns]

# %% [markdown]
# sorting the no.of models with year of model made by each maker in ascending order with perticular model

# %%
modelyear.groupby(['Model Year','Make','Model'])['Model'].count().reset_index(name='total').head(25)
# Out:
#     Model Year                  Make                     Model  total
# 0         1997             CHEVROLET               S-10 PICKUP      1
# 1         1998                  FORD                    RANGER      1
# 2         1999                  FORD                    RANGER      4
# 3         2000                  FORD                    RANGER      9
# 4         2002                TOYOTA                      RAV4      2
# 5         2003                TOYOTA                      RAV4      1
# 6         2008                 TESLA                  ROADSTER     21
# 7         2010                 TESLA                  ROADSTER     21
# 8         2010  WHEEGO ELECTRIC CARS                    WHEEGO      3
# 9         2011        AZURE DYNAMICS  TRANSIT CONNECT ELECTRIC      4
# 10        2011             CHEVROLET                      VOLT     75
# 11        2011                NISSAN                      LEAF    720
# ...

# %%
modelyear.groupby(['Model Year','Make','Model'])['Model'].count().reset_index(name='total').tail(25).sort_values(by='total',ascending=False)
# Out:
#      Model Year        Make       Model  total
# 397        2023       TESLA     MODEL Y   5464
# 394        2023       TESLA     MODEL 3   2405
# 400        2023  VOLKSWAGEN        ID.4    699
# 396        2023       TESLA     MODEL X    487
# 386        2023      NISSAN        LEAF    438
# 392        2023      RIVIAN         R1T    219
# 383        2023        MINI     HARDTOP    203
# 387        2023    POLESTAR         PS2    177
# 393        2023      SUBARU    SOLTERRA    167
# 406        2023       VOLVO        XC60    157
# 407        2023       VOLVO        XC90    151
# 399        2023      TOYOTA  RAV4 PRIME    141
# 384        2023  MITSUBISHI   OUTLANDER    118
# 401        2023       VOLVO         C40    118
# 395        2023       TESLA     MODEL S    116
# 391        2023      RIVIAN         R1S    113
# 385        2023      NISSAN       ARIYA     62
# 398        2023      TOYOTA        BZ4X     42
# 390        2023     PORSCHE      TAYCAN     39
# ...

# %% [markdown]
# # data set with of different type of electric vehicle type and model made by each maker with year of model and order these by total no.of models in ascending order.

# %%
electric_vehicle_data.groupby(['Model Year','Make','Model','Electric Vehicle Type'])['Model'].count().reset_index(name='total').head(50)
# Out:
#     Model Year                  Make                     Model  \
# 0         1997             CHEVROLET               S-10 PICKUP
# 1         1998                  FORD                    RANGER
# 2         1999                  FORD                    RANGER
# 3         2000                  FORD                    RANGER
# 4         2002                TOYOTA                      RAV4
# 5         2003                TOYOTA                      RAV4
# 6         2008                 TESLA                  ROADSTER
# 7         2010                 TESLA                  ROADSTER
# 8         2010  WHEEGO ELECTRIC CARS                    WHEEGO
# 9         2011        AZURE DYNAMICS  TRANSIT CONNECT ELECTRIC
# 10        2011             CHEVROLET                      VOLT
# 11        2011                NISSAN                      LEAF
# 12        2011                 TESLA                  ROADSTER
# 13        2011                 TH!NK                      CITY
# ...

# %% [markdown]
# # filter the data with Electric Range of above 200

# %%
eleRange=electric_vehicle_data[electric_vehicle_data['Electric Range']>200]

# %%
eleRange
# Out:
#         VIN (1-10)    County           City State  Postal Code  Model Year  \
# 0       5YJXCAE26J    Yakima         Yakima    WA      98908.0        2018
# 2       5YJ3E1EB0K      King        Seattle    WA      98199.0        2019
# 4       5YJSA1E21H  Thurston          Lacey    WA      98516.0        2017
# 9       5YJSA1CP1D    Kitsap      Bremerton    WA      98312.0        2013
# 12      5YJ3E1EC7L  Thurston          Lacey    WA      98503.0        2020
# ...            ...       ...            ...   ...          ...         ...
# 130417  5YJYGDEE5L    Pierce         Tacoma    WA      98444.0        2020
# 130418  5YJSA1E22F      King         Vashon    WA      98070.0        2015
# 130432  5YJYGDEEXL      King         Vashon    WA      98070.0        2020
# 130436  5YJ3E1EB0J   Whatcom         Blaine    WA      98230.0        2018
# 130441  5YJXCBE22L    Island  Camano Island    WA      98282.0        2020
#
#          Make    Model           Electric Vehicle Type  \
# ...

# %%
eleRange.shape
# Out:
# (30262, 14)

# %% [markdown]
# # data set with having the electric range of below 200

# %%
elebelowRange=electric_vehicle_data[electric_vehicle_data['Electric Range']<200]

# %%
elebelowRange
# Out:
#         VIN (1-10)    County        City State  Postal Code  Model Year  \
# 1       JHMZC5F37M    Kitsap     Poulsbo    WA      98370.0        2021
# 3       1N4AZ0CP5D      King     Seattle    WA      98119.0        2013
# 5       JHMZC5F1XJ  Thurston     Olympia    WA      98506.0        2018
# 6       3FA6P0PU1G  Thurston    Tumwater    WA      98501.0        2016
# 7       WA1F2AFY8P  Thurston       Lacey    WA      98516.0        2023
# ...            ...       ...         ...   ...          ...         ...
# 130437  WBA13AG06M  Thurston     Olympia    WA      98501.0        2021
# 130438  7SAYGDEE6P    Pierce  Gig Harbor    WA      98335.0        2023
# 130439  1N4BZ1CV7N    Pierce      Tacoma    WA      98408.0        2022
# 130440  5YJYGDEE8M      King     Seattle    WA      98109.0        2021
# 130442  5YJ3E1EA5M    Pierce    Puyallup    WA      98375.0        2021
#
#           Make    Model                   Electric Vehicle Type  \
# ...

# %%
elebelowRange.shape
# Out:
# (98873, 14)

# %% [markdown]
# # Two Types of vehicles based on electric vehicle type

# %%
electric_vehicle_data.groupby(['Electric Vehicle Type'])['Model'].count().reset_index(name='no.of.electric_vehicles')
# Out:
#                     Electric Vehicle Type  no.of.electric_vehicles
# 0          Battery Electric Vehicle (BEV)                    99934
# 1  Plug-in Hybrid Electric Vehicle (PHEV)                    30287

# %%
electric_vehicle_data.groupby(['Legislative District','Make'])['Model'].count().reset_index(name='no.of_evehicles_in_leg.area').head(40)
# Out:
#     Legislative District           Make  no.of_evehicles_in_leg.area
# 0                    1.0           AUDI                           79
# 1                    1.0            BMW                          214
# 2                    1.0       CADILLAC                            2
# 3                    1.0      CHEVROLET                          295
# 4                    1.0       CHRYSLER                           89
# 5                    1.0           FIAT                           18
# 6                    1.0           FORD                          226
# 7                    1.0        GENESIS                            3
# 8                    1.0          HONDA                           27
# 9                    1.0        HYUNDAI                           75
# 10                   1.0         JAGUAR                           14
# 11                   1.0           JEEP                           58
# 12                   1.0            KIA                          184
# ...

# %% [markdown]
# # filter the data depending upon the electric_vehicle in leagal area. and shown no.of models made by each maker in each legal area wiht their legar district as shown below.

# %%
electric_vehicle_data.groupby(['Legislative District','Make'])['Model'].count().reset_index(name='no.of_evehicles_in_leg.area').tail(40)
# Out:
#       Legislative District           Make  no.of_evehicles_in_leg.area
# 1346                  48.0         NISSAN                          586
# 1347                  48.0       POLESTAR                           39
# 1348                  48.0        PORSCHE                          113
# 1349                  48.0         RIVIAN                           82
# 1350                  48.0          SMART                           15
# 1351                  48.0         SUBARU                            5
# 1352                  48.0          TESLA                         4500
# 1353                  48.0          TH!NK                            1
# 1354                  48.0         TOYOTA                          150
# 1355                  48.0     VOLKSWAGEN                          130
# 1356                  48.0          VOLVO                          143
# 1357                  49.0           AUDI                           24
# ...

# %%
electric_vehicle_data.groupby(['Legislative District','Make'])['Model'].count().reset_index(name='avg_no.of_evehicles_in_leg.area').tail(40)
# Out:
#       Legislative District           Make  avg_no.of_evehicles_in_leg.area
# 1346                  48.0         NISSAN                              586
# 1347                  48.0       POLESTAR                               39
# 1348                  48.0        PORSCHE                              113
# 1349                  48.0         RIVIAN                               82
# 1350                  48.0          SMART                               15
# 1351                  48.0         SUBARU                                5
# 1352                  48.0          TESLA                             4500
# 1353                  48.0          TH!NK                                1
# 1354                  48.0         TOYOTA                              150
# 1355                  48.0     VOLKSWAGEN                              130
# 1356                  48.0          VOLVO                              143
# ...

# %% [markdown]
# # no.of models made by each maker with their electric utility and maker as shown below

# %%
electric_vehicle_data.groupby(['Electric Utility','Make'])['Model'].count().reset_index(name='no.of_electric_utility_models').head(40)
# Out:
#                                      Electric Utility           Make  \
# 0                                         AVISTA CORP           AUDI
# 1                                         AVISTA CORP            BMW
# 2                                         AVISTA CORP      CHEVROLET
# 3                                         AVISTA CORP       CHRYSLER
# 4                                         AVISTA CORP           FORD
# 5                                         AVISTA CORP          HONDA
# 6                                         AVISTA CORP        HYUNDAI
# 7                                         AVISTA CORP         JAGUAR
# 8                                         AVISTA CORP           JEEP
# 9                                         AVISTA CORP            KIA
# 10                                        AVISTA CORP  MERCEDES-BENZ
# 11                                        AVISTA CORP           MINI
# 12                                        AVISTA CORP     MITSUBISHI
# ...

# %%
electric_vehicle_data.groupby(['Electric Utility','Make'])['Model'].count().reset_index(name='no.of_electric_utility_models').tail(40)
# Out:
#                                        Electric Utility            Make  \
# 1176      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)         PORSCHE
# 1177      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)          RIVIAN
# 1178      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)           SMART
# 1179      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)          SUBARU
# 1180      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)           TESLA
# 1181      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)           TH!NK
# 1182      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)          TOYOTA
# 1183      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)      VOLKSWAGEN
# 1184      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)           VOLVO
# 1185  PUGET SOUND ENERGY INC||PUD NO 1 OF WHATCOM CO...            AUDI
# 1186  PUGET SOUND ENERGY INC||PUD NO 1 OF WHATCOM CO...  AZURE DYNAMICS
# 1187  PUGET SOUND ENERGY INC||PUD NO 1 OF WHATCOM CO...             BMW
# ...

# %% [markdown]
# # filter the data by clean alternative fuel vehicle eligibility with their maker and no.of models made in year of model as shown below.

# %%
electric_vehicle_data.groupby(['Clean Alternative Fuel Vehicle (CAFV) Eligibility','Make','Model Year'])['Model'].count().reset_index(name='total_CAFV_eligible_Models').head(40)
# Out:
#    Clean Alternative Fuel Vehicle (CAFV) Eligibility            Make  \
# 0            Clean Alternative Fuel Vehicle Eligible            AUDI
# 1            Clean Alternative Fuel Vehicle Eligible            AUDI
# 2            Clean Alternative Fuel Vehicle Eligible            AUDI
# 3            Clean Alternative Fuel Vehicle Eligible  AZURE DYNAMICS
# 4            Clean Alternative Fuel Vehicle Eligible  AZURE DYNAMICS
# 5            Clean Alternative Fuel Vehicle Eligible             BMW
# 6            Clean Alternative Fuel Vehicle Eligible             BMW
# 7            Clean Alternative Fuel Vehicle Eligible             BMW
# 8            Clean Alternative Fuel Vehicle Eligible             BMW
# 9            Clean Alternative Fuel Vehicle Eligible             BMW
# 10           Clean Alternative Fuel Vehicle Eligible             BMW
# 11           Clean Alternative Fuel Vehicle Eligible             BMW
# 12           Clean Alternative Fuel Vehicle Eligible             BMW
# ...

# %%
electric_vehicle_data.groupby(['Clean Alternative Fuel Vehicle (CAFV) Eligibility','Make','Model Year'])['Model'].count().reset_index(name='total_CAFV_eligible_Models').tail(40)
# Out:
#     Clean Alternative Fuel Vehicle (CAFV) Eligibility           Make  \
# 249             Not eligible due to low battery range  MERCEDES-BENZ
# 250             Not eligible due to low battery range           MINI
# 251             Not eligible due to low battery range           MINI
# 252             Not eligible due to low battery range           MINI
# 253             Not eligible due to low battery range           MINI
# 254             Not eligible due to low battery range           MINI
# 255             Not eligible due to low battery range           MINI
# 256             Not eligible due to low battery range     MITSUBISHI
# 257             Not eligible due to low battery range     MITSUBISHI
# 258             Not eligible due to low battery range     MITSUBISHI
# 259             Not eligible due to low battery range     MITSUBISHI
# 260             Not eligible due to low battery range     MITSUBISHI
# 261             Not eligible due to low battery range        PORSCHE
# ...

# %%
postal=electric_vehicle_data.groupby(['Postal Code','Make','Model Year','State'])['Model'].count().reset_index(name='toal_no.of_model_postal Code_wise')

# %%
postal
# Out:
#        Postal Code        Make  Model Year State  \
# 0           1730.0   CHEVROLET        2018    MA
# 1           1731.0       TESLA        2022    MA
# 2           1824.0       TESLA        2022    MA
# 3           2842.0      NISSAN        2014    RI
# 4           3804.0       TESLA        2020    NH
# ...            ...         ...         ...   ...
# 26890      99403.0      TOYOTA        2018    WA
# 26891      99403.0      TOYOTA        2020    WA
# 26892      99403.0      TOYOTA        2021    WA
# 26893      99403.0  VOLKSWAGEN        2021    WA
# 26894      99701.0        FORD        2016    AK
#
#        toal_no.of_model_postal Code_wise
# 0                                      1
# 1                                      1
# 2                                      1
# 3                                      1
# 4                                      1
# ...                                  ...
# 26890                                  1
# ...

# %%
postal_Make=postal.sort_values(by='Model Year',ascending=False)

# %%
postal_Make
# Out:
#        Postal Code       Make  Model Year State  \
# 18872      98502.0      VOLVO        2023    WA
# 3045       98032.0       JEEP        2023    WA
# 3026       98032.0  CHEVROLET        2023    WA
# 6451       98103.0     NISSAN        2023    WA
# 25931      99223.0     TOYOTA        2023    WA
# ...            ...        ...         ...   ...
# 14966      98338.0       FORD        1999    WA
# 13059      98274.0       FORD        1999    WA
# 11711      98244.0       FORD        1999    WA
# 16591      98382.0       FORD        1998    WA
# 12677      98270.0  CHEVROLET        1997    WA
#
#        toal_no.of_model_postal Code_wise
# 18872                                  4
# 3045                                   2
# 3026                                   3
# 6451                                   9
# 25931                                  1
# ...                                  ...
# 14966                                  2
# 13059                                  1
# ...

# %%
postal_Make[postal_Make['Make']=='TESLA'].head(40)
# Out:
#        Postal Code   Make  Model Year State  toal_no.of_model_postal Code_wise
# 21500      98645.0  TESLA        2023    WA                                  2
# 24832      99109.0  TESLA        2023    WA                                  1
# 25926      99223.0  TESLA        2023    WA                                 19
# 18224      98465.0  TESLA        2023    WA                                  1
# 24813      99037.0  TESLA        2023    WA                                  4
# 6480       98103.0  TESLA        2023    WA                                 69
# 2989       98031.0  TESLA        2023    WA                                 95
# 24818      99101.0  TESLA        2023    WA                                  1
# 13112      98274.0  TESLA        2023    WA                                 10
# 13028      98273.0  TESLA        2023    WA                                  7
# 10441      98203.0  TESLA        2023    WA                                 16
# ...

# %% [markdown]
# # No.of models made by tesla in perticular postal code in different states in different year of modes order by model year as shown below.

# %%
postal_Make[postal_Make['Make']=='TESLA'].tail(40)
# Out:
#        Postal Code   Make  Model Year State  toal_no.of_model_postal Code_wise
# 3217       98033.0  TESLA        2011    WA                                  1
# 13208      98275.0  TESLA        2010    WA                                  1
# 6195       98101.0  TESLA        2010    WA                                  1
# 691        98004.0  TESLA        2010    WA                                  1
# 16877      98388.0  TESLA        2010    WA                                  1
# 20719      98606.0  TESLA        2010    WA                                  1
# 2527       98027.0  TESLA        2010    WA                                  1
# 6316       98102.0  TESLA        2010    WA                                  1
# 11996      98249.0  TESLA        2010    WA                                  1
# 9131       98144.0  TESLA        2010    WA                                  1
# 957        98006.0  TESLA        2010    WA                                  2
# ...

# %% [markdown]
# # Filter the data of no.of models made by perticular maker with respect to perticular country.

# %%
electric_vehicle_data.groupby(['County'])['Model'].count().reset_index(name='County wise_no.of_Models')
# Out:
#            County  County wise_no.of_Models
# 0           Adams                        39
# 1         Alameda                         3
# 2      Alexandria                         6
# 3           Allen                         1
# 4    Anne Arundel                        10
# ..            ...                       ...
# 161       Whatcom                      3221
# 162       Whitman                       222
# 163       Wichita                         2
# 164        Yakima                       709
# 165       Yavapai                         1
#
# [166 rows x 2 columns]

# %%
electric_vehicle_data.groupby(['County','Postal Code','State','Make'])['Model'].count().reset_index(name='no.of_models_county wise').head(20)
# Out:
#         County  Postal Code State       Make  no.of_models_county wise
# 0        Adams      80019.0    CO      TESLA                         1
# 1        Adams      99169.0    WA        BMW                         1
# 2        Adams      99169.0    WA  CHEVROLET                         2
# 3        Adams      99169.0    WA       FORD                         4
# 4        Adams      99169.0    WA       JEEP                         1
# 5        Adams      99169.0    WA     RIVIAN                         1
# 6        Adams      99169.0    WA      TESLA                         4
# 7        Adams      99341.0    WA   CHRYSLER                         1
# 8        Adams      99341.0    WA     RIVIAN                         1
# 9        Adams      99344.0    WA       AUDI                         1
# 10       Adams      99344.0    WA  CHEVROLET                         4
# 11       Adams      99344.0    WA       FORD                         2
# ...

# %%
electric_vehicle_data.groupby(['County','Postal Code','State','Make'])['Model'].count().reset_index(name='no.of_models_county wise').tail(20)
# Out:
#        County  Postal Code State        Make  no.of_models_county wise
# 7448   Yakima      98948.0    WA      TOYOTA                         1
# 7449   Yakima      98951.0    WA   CHEVROLET                         1
# 7450   Yakima      98951.0    WA    CHRYSLER                         1
# 7451   Yakima      98951.0    WA         KIA                         1
# 7452   Yakima      98951.0    WA       TESLA                         5
# 7453   Yakima      98951.0    WA  VOLKSWAGEN                         1
# 7454   Yakima      98952.0    WA        FORD                         1
# 7455   Yakima      98952.0    WA        JEEP                         1
# 7456   Yakima      98953.0    WA         BMW                         3
# 7457   Yakima      98953.0    WA        FORD                         3
# 7458   Yakima      98953.0    WA      JAGUAR                         1
# 7459   Yakima      98953.0    WA        JEEP                         1
# ...
