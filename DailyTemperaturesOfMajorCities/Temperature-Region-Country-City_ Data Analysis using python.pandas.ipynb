# %%
import pandas as pd

# %%
temp_table=pd.read_csv('city_temperature.csv')
# Out:
# C:\Users\mahen\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (2) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
temp_table
# Out:
#                 Region  Country                   State                  City  \
# 0               Africa  Algeria                     NaN               Algiers
# 1               Africa  Algeria                     NaN               Algiers
# 2               Africa  Algeria                     NaN               Algiers
# 3               Africa  Algeria                     NaN               Algiers
# 4               Africa  Algeria                     NaN               Algiers
# ...                ...      ...                     ...                   ...
# 2906322  North America       US  Additional Territories  San Juan Puerto Rico
# 2906323  North America       US  Additional Territories  San Juan Puerto Rico
# 2906324  North America       US  Additional Territories  San Juan Puerto Rico
# 2906325  North America       US  Additional Territories  San Juan Puerto Rico
# 2906326  North America       US  Additional Territories  San Juan Puerto Rico
#
# ...

# %%
temp_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2906327 entries, 0 to 2906326
# Data columns (total 8 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   Region          object
#  1   Country         object
#  2   State           object
#  3   City            object
#  4   Month           int64
#  5   Day             int64
#  6   Year            int64
#  7   AvgTemperature  float64
# dtypes: float64(1), int64(3), object(4)
# memory usage: 177.4+ MB

# %%
temp_table.describe()
# Out:
#               Month           Day          Year  AvgTemperature
# count  2.906327e+06  2.906327e+06  2.906327e+06    2.906327e+06
# mean   6.469163e+00  1.571682e+01  2.006624e+03    5.600492e+01
# std    3.456489e+00  8.800534e+00  2.338226e+01    3.212359e+01
# min    1.000000e+00  0.000000e+00  2.000000e+02   -9.900000e+01
# 25%    3.000000e+00  8.000000e+00  2.001000e+03    4.580000e+01
# 50%    6.000000e+00  1.600000e+01  2.007000e+03    6.250000e+01
# 75%    9.000000e+00  2.300000e+01  2.013000e+03    7.550000e+01
# max    1.200000e+01  3.100000e+01  2.020000e+03    1.100000e+02

# %%
temp_table['Year'].max()
# Out:
# 2020

# %%
temp_table['Year'].min()
# Out:
# 200

# %%
temp_table.sort_values(by='Year',ascending=True).head(100)
# Out:
#         Region   Country State         City  Month  Day  Year  AvgTemperature
# 743771  Europe   Germany   NaN      Hamburg     12   12   200           -99.0
# 845936  Europe    Norway   NaN         Oslo     12   28   200           -99.0
# 845935  Europe    Norway   NaN         Oslo     12   27   200           -99.0
# 845934  Europe    Norway   NaN         Oslo     12   26   200           -99.0
# 845933  Europe    Norway   NaN         Oslo     12   25   200           -99.0
# ...        ...       ...   ...          ...    ...  ...   ...             ...
# 58193   Africa  Ethiopia   NaN  Addis Ababa     12   18   201           -99.0
# 58192   Africa  Ethiopia   NaN  Addis Ababa     12   17   201           -99.0
# 58190   Africa  Ethiopia   NaN  Addis Ababa     12   15   201           -99.0
# 58195   Africa  Ethiopia   NaN  Addis Ababa     12   20   201           -99.0
# 744160  Europe   Germany   NaN      Hamburg     12    6   201           -99.0
#
# [100 rows x 8 columns]

# %%
temp_table.size
# Out:
# 23250616

# %%
temp_table.shape
# Out:
# (2906327, 8)

# %%
temp_table[temp_table['Year']>2000]
# Out:
#                 Region  Country                   State                  City  \
# 2192            Africa  Algeria                     NaN               Algiers
# 2193            Africa  Algeria                     NaN               Algiers
# 2194            Africa  Algeria                     NaN               Algiers
# 2195            Africa  Algeria                     NaN               Algiers
# 2196            Africa  Algeria                     NaN               Algiers
# ...                ...      ...                     ...                   ...
# 2906322  North America       US  Additional Territories  San Juan Puerto Rico
# 2906323  North America       US  Additional Territories  San Juan Puerto Rico
# 2906324  North America       US  Additional Territories  San Juan Puerto Rico
# 2906325  North America       US  Additional Territories  San Juan Puerto Rico
# 2906326  North America       US  Additional Territories  San Juan Puerto Rico
#
# ...

# %%
temp_table[temp_table['Country']=='Algeria']
# Out:
#       Region  Country State     City  Month  Day  Year  AvgTemperature
# 0     Africa  Algeria   NaN  Algiers      1    1  1995            64.2
# 1     Africa  Algeria   NaN  Algiers      1    2  1995            49.4
# 2     Africa  Algeria   NaN  Algiers      1    3  1995            48.8
# 3     Africa  Algeria   NaN  Algiers      1    4  1995            46.4
# 4     Africa  Algeria   NaN  Algiers      1    5  1995            47.9
# ...      ...      ...   ...      ...    ...  ...   ...             ...
# 9261  Africa  Algeria   NaN  Algiers      5    9  2020            70.8
# 9262  Africa  Algeria   NaN  Algiers      5   10  2020            67.1
# 9263  Africa  Algeria   NaN  Algiers      5   11  2020            68.9
# 9264  Africa  Algeria   NaN  Algiers      5   12  2020            69.8
# 9265  Africa  Algeria   NaN  Algiers      5   13  2020            60.8
#
# [9266 rows x 8 columns]

# %%
temp_table.isnull().sum()
# Out:
# Region                  0
# Country                 0
# State             1450990
# City                    0
# Month                   0
# Day                     0
# Year                    0
# AvgTemperature          0
# dtype: int64

# %%
temp_table.drop(['State'],axis=1,inplace=True)

# %%
temp_table
# Out:
#                 Region  Country                  City  Month  Day  Year  \
# 0               Africa  Algeria               Algiers      1    1  1995
# 1               Africa  Algeria               Algiers      1    2  1995
# 2               Africa  Algeria               Algiers      1    3  1995
# 3               Africa  Algeria               Algiers      1    4  1995
# 4               Africa  Algeria               Algiers      1    5  1995
# ...                ...      ...                   ...    ...  ...   ...
# 2906322  North America       US  San Juan Puerto Rico      7   27  2013
# 2906323  North America       US  San Juan Puerto Rico      7   28  2013
# 2906324  North America       US  San Juan Puerto Rico      7   29  2013
# 2906325  North America       US  San Juan Puerto Rico      7   30  2013
# 2906326  North America       US  San Juan Puerto Rico      7   31  2013
#
#          AvgTemperature
# 0                  64.2
# 1                  49.4
# 2                  48.8
# ...

# %%
temp_table[temp_table['Region']=='North America'].shape
# Out:
# (1556681, 7)

# %%
temp_table[temp_table['Region']=='Africa'].shape
# Out:
# (251118, 7)

# %%
temp_table['Region'].unique()
# Out:
# array(['Africa', 'Asia', 'Australia/South Pacific', 'Europe',
#        'Middle East', 'North America',
#        'South/Central America & Carribean'], dtype=object)

# %%
temp_table['Region'].unique().size
# Out:
# 7

# %%
temp_table[temp_table['Region']=='Asia'].shape
# Out:
# (316663, 7)

# %%
temp_table['Country'].unique().shape
# Out:
# (125,)

# %%
temp_table
# Out:
#                 Region  Country                  City  Month  Day  Year  \
# 0               Africa  Algeria               Algiers      1    1  1995
# 1               Africa  Algeria               Algiers      1    2  1995
# 2               Africa  Algeria               Algiers      1    3  1995
# 3               Africa  Algeria               Algiers      1    4  1995
# 4               Africa  Algeria               Algiers      1    5  1995
# ...                ...      ...                   ...    ...  ...   ...
# 2906322  North America       US  San Juan Puerto Rico      7   27  2013
# 2906323  North America       US  San Juan Puerto Rico      7   28  2013
# 2906324  North America       US  San Juan Puerto Rico      7   29  2013
# 2906325  North America       US  San Juan Puerto Rico      7   30  2013
# 2906326  North America       US  San Juan Puerto Rico      7   31  2013
#
#          AvgTemperature
# 0                  64.2
# 1                  49.4
# 2                  48.8
# ...

# %%
temp_table
# Out:
#                 Region  Country                  City  Month  Day  Year  \
# 0               Africa  Algeria               Algiers      1    1  1995
# 1               Africa  Algeria               Algiers      1    2  1995
# 2               Africa  Algeria               Algiers      1    3  1995
# 3               Africa  Algeria               Algiers      1    4  1995
# 4               Africa  Algeria               Algiers      1    5  1995
# ...                ...      ...                   ...    ...  ...   ...
# 2906322  North America       US  San Juan Puerto Rico      7   27  2013
# 2906323  North America       US  San Juan Puerto Rico      7   28  2013
# 2906324  North America       US  San Juan Puerto Rico      7   29  2013
# 2906325  North America       US  San Juan Puerto Rico      7   30  2013
# 2906326  North America       US  San Juan Puerto Rico      7   31  2013
#
#          AvgTemperature
# 0                  64.2
# 1                  49.4
# 2                  48.8
# ...

# %%
temp_table[temp_table['Year']>2000].shape
# Out:
# (2191545, 7)

# %%
x=temp_table['AvgTemperature'].max()

# %%
x
# Out:
# 110.0

# %%
temp_table[temp_table['AvgTemperature']==x]
# Out:
#               Region Country    City  Month  Day  Year  AvgTemperature
# 1034962  Middle East  Kuwait  Kuwait      8    1  2012           110.0

# %%
y=temp_table['AvgTemperature'].min()

# %%
y
# Out:
# -99.0

# %%
temp_table[temp_table['AvgTemperature']==y]
# Out:
#                 Region  Country                  City  Month  Day  Year  \
# 220             Africa  Algeria               Algiers      8    9  1995
# 221             Africa  Algeria               Algiers      8   10  1995
# 408             Africa  Algeria               Algiers      2   13  1996
# 409             Africa  Algeria               Algiers      2   14  1996
# 1453            Africa  Algeria               Algiers     12   24  1998
# ...                ...      ...                   ...    ...  ...   ...
# 2905471  North America       US  San Juan Puerto Rico      3   29  2011
# 2905534  North America       US  San Juan Puerto Rico      5   31  2011
# 2905689  North America       US  San Juan Puerto Rico     11    2  2011
# 2905726  North America       US  San Juan Puerto Rico     12    9  2011
# 2905749  North America       US  San Juan Puerto Rico      1    1  2012
#
#          AvgTemperature
# 220               -99.0
# 221               -99.0
# 408               -99.0
# ...

# %%
twenteethcentury=temp_table['Year']>=2000

# %%
twc=temp_table[twenteethcentury].sort_values(by='Year',ascending=False)

# %%
twc
# Out:
#                 Region Country        City  Month  Day  Year  AvgTemperature
# 1644232  North America      US      Pueblo      5    2  2020            68.7
# 1841009  North America      US     Chicago      4    7  2020            62.7
# 1841035  North America      US     Chicago      5    3  2020            66.8
# 1841034  North America      US     Chicago      5    2  2020            65.3
# 1841033  North America      US     Chicago      5    1  2020            52.0
# ...                ...     ...         ...    ...  ...   ...             ...
# 1815080  North America      US       Boise      1    4  2000            34.4
# 1815081  North America      US       Boise      1    5  2000            31.7
# 1815082  North America      US       Boise      1    6  2000            27.3
# 1815083  North America      US       Boise      1    7  2000            30.3
# 1462205  North America      US  Huntsville      5    4  2000            72.0
#
# [2311227 rows x 7 columns]

# %%
v=twc['AvgTemperature'].min()

# %%
twc[twc['AvgTemperature']==v]
# Out:
#                                     Region    Country       City  Month  Day  \
# 651158                              Europe    Belarus      Minsk      4   27
# 651160                              Europe    Belarus      Minsk      4   29
# 651161                              Europe    Belarus      Minsk      4   30
# 651163                              Europe    Belarus      Minsk      5    2
# 651166                              Europe    Belarus      Minsk      5    5
# ...                                    ...        ...        ...    ...  ...
# 1443910  South/Central America & Carribean  Venezuela    Caracas     12   25
# 1443914  South/Central America & Carribean  Venezuela    Caracas     12   29
# 1434619  South/Central America & Carribean    Uruguay  Montvideo     11   30
# 1443885  South/Central America & Carribean  Venezuela    Caracas     11   30
# 1954199                      North America         US  Lexington      5   27
#
#          Year  AvgTemperature
# ...

# %%
twc.shape
# Out:
# (2311227, 7)

# %%
temp_table.shape
# Out:
# (2906327, 7)

# %%
h=twc['AvgTemperature'].max()

# %%
h
# Out:
# 110.0

# %%
twc[twc[['AvgTemperature','Year','Region']]['Region']=='Africa']
# Out:
#         Region  Country        City  Month  Day  Year  AvgTemperature
# 69425   Africa    Gabon  Libreville      5    8  2020            79.1
# 69426   Africa    Gabon  Libreville      5    9  2020            82.0
# 69427   Africa    Gabon  Libreville      5   10  2020            81.5
# 69428   Africa    Gabon  Libreville      5   11  2020            82.2
# 69429   Africa    Gabon  Libreville      5   12  2020            84.1
# ...        ...      ...         ...    ...  ...   ...             ...
# 115794  Africa  Morocco       Rabat      1    4  2000            53.1
# 115795  Africa  Morocco       Rabat      1    5  2000            52.1
# 115796  Africa  Morocco       Rabat      1    6  2000            52.4
# 115797  Africa  Morocco       Rabat      1    7  2000            48.6
# 1827    Africa  Algeria     Algiers      1    2  2000            46.5
#
# [199419 rows x 7 columns]

# %%
l=twc['AvgTemperature'].min()

# %%
twc[twc['AvgTemperature']==l].head()
# Out:
#         Region  Country   City  Month  Day  Year  AvgTemperature
# 651158  Europe  Belarus  Minsk      4   27  2020           -99.0
# 651160  Europe  Belarus  Minsk      4   29  2020           -99.0
# 651161  Europe  Belarus  Minsk      4   30  2020           -99.0
# 651163  Europe  Belarus  Minsk      5    2  2020           -99.0
# 651166  Europe  Belarus  Minsk      5    5  2020           -99.0

# %%
temp_table
# Out:
#                 Region  Country                  City  Month  Day  Year  \
# 0               Africa  Algeria               Algiers      1    1  1995
# 1               Africa  Algeria               Algiers      1    2  1995
# 2               Africa  Algeria               Algiers      1    3  1995
# 3               Africa  Algeria               Algiers      1    4  1995
# 4               Africa  Algeria               Algiers      1    5  1995
# ...                ...      ...                   ...    ...  ...   ...
# 2906322  North America       US  San Juan Puerto Rico      7   27  2013
# 2906323  North America       US  San Juan Puerto Rico      7   28  2013
# 2906324  North America       US  San Juan Puerto Rico      7   29  2013
# 2906325  North America       US  San Juan Puerto Rico      7   30  2013
# 2906326  North America       US  San Juan Puerto Rico      7   31  2013
#
#          AvgTemperature
# 0                  64.2
# 1                  49.4
# 2                  48.8
# ...

# %%
twc[['Year','AvgTemperature']].describe()
# Out:
#                Year  AvgTemperature
# count  2.311227e+06    2.311227e+06
# mean   2.009443e+03    5.730668e+01
# std    5.865884e+00    2.940150e+01
# min    2.000000e+03   -9.900000e+01
# 25%    2.004000e+03    4.630000e+01
# 50%    2.009000e+03    6.290000e+01
# 75%    2.014000e+03    7.590000e+01
# max    2.020000e+03    1.100000e+02

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
highest=twc['AvgTemperature'].max()

# %%
highest
# Out:
# 110.0

# %%
pp=twc[twc['AvgTemperature']==highest]
ii=twc.sort_values(by='AvgTemperature',ascending=False).head()
ii
# Out:
#               Region Country    City  Month  Day  Year  AvgTemperature
# 1034962  Middle East  Kuwait  Kuwait      8    1  2012           110.0
# 1036042  Middle East  Kuwait  Kuwait      7   17  2015           109.9
# 1036756  Middle East  Kuwait  Kuwait      6   29  2017           109.9
# 1034963  Middle East  Kuwait  Kuwait      8    2  2012           109.9
# 1032390  Middle East  Kuwait  Kuwait      7   17  2005           109.9

# %%
sns.set(rc={'figure.figsize':(8,1)})
ax=sns.barplot(x='Year',y='AvgTemperature',data=ii)
ax.set_ylim(0,150)
# Out:
# (0.0, 150.0)

# %%
sns.set(rc={'figure.figsize':(20,7)})
ax=sns.barplot(x='Year',y='AvgTemperature',data=twc)
ax.set_ylim(0,110)
# Out:
# (0.0, 110.0)

# %%
yy=twc['AvgTemperature'].min()
ll=twc[twc['AvgTemperature']<=yy].tail()
ll['AvgTemperature'].unique()
# Out:
# array([-99.])

# %%
ll
# Out:
#                                     Region    Country       City  Month  Day  \
# 1443910  South/Central America & Carribean  Venezuela    Caracas     12   25
# 1443914  South/Central America & Carribean  Venezuela    Caracas     12   29
# 1434619  South/Central America & Carribean    Uruguay  Montvideo     11   30
# 1443885  South/Central America & Carribean  Venezuela    Caracas     11   30
# 1954199                      North America         US  Lexington      5   27
#
#          Year  AvgTemperature
# 1443910  2000           -99.0
# 1443914  2000           -99.0
# 1434619  2000           -99.0
# 1443885  2000           -99.0
# 1954199  2000           -99.0

# %%
sns.set(rc={'figure.figsize':(10,5)})
ax=sns.barplot(x='Year',y='AvgTemperature',data=ll)
ax.set_ylim(-100,10)
# Out:
# (-100.0, 10.0)
